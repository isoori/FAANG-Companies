# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.dates as mandates

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
from sklearn import linear_model

from keras.layers import LSTM, Dense, Dropout
from keras.models import Sequential

# %%
data = pd.read_csv('Google_Historical_StockPrice2.csv')
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-03-28  736.789978  738.989990  732.500000  733.530029  733.530029
# 1  2016-03-29  734.590027  747.250000  728.760010  744.770020  744.770020
# 2  2016-03-30  750.099976  757.880005  748.739990  750.530029  750.530029
# 3  2016-03-31  749.250000  750.849976  740.940002  744.950012  744.950012
# 4  2016-04-01  738.599976  750.340027  737.000000  749.909973  749.909973
#
#     Volume
# 0  1301300
# 1  1903800
# 2  1782400
# 3  1718800
# 4  1576700

# %%
data['Adj Close'].plot()
# Out:
# <AxesSubplot:>

# %%
features = ['Open' , 'High', 'Low','Volume']
feature_tf = data[features]
feature_tf
# Out:
#              Open         High          Low   Volume
# 0      736.789978   738.989990   732.500000  1301300
# 1      734.590027   747.250000   728.760010  1903800
# 2      750.099976   757.880005   748.739990  1782400
# 3      749.250000   750.849976   740.940002  1718800
# 4      738.599976   750.340027   737.000000  1576700
# ...           ...          ...          ...      ...
# 1255  2041.839966  2057.989990  2026.069946  1954800
# 1256  2051.699951  2072.302002  2039.219971  1367000
# 1257  2065.370117  2078.209961  2041.555054  1154000
# 1258  2044.810059  2058.870117  2010.729980  1418900
# 1259  2038.859985  2050.989990  2014.020020  1493500
#
# [1260 rows x 4 columns]

# %%
close_price = data['Adj Close']
close_price = pd.DataFrame(data=close_price.values.ravel(), columns=['Adj Close'],index=data['Date'])
close_price
# Out:
#               Adj Close
# Date
# 2016-03-28   733.530029
# 2016-03-29   744.770020
# 2016-03-30   750.530029
# 2016-03-31   744.950012
# 2016-04-01   749.909973
# ...                 ...
# 2021-03-22  2038.589966
# 2021-03-23  2052.959961
# 2021-03-24  2045.060059
# 2021-03-25  2044.359985
# 2021-03-26  2035.550049
#
# [1260 rows x 1 columns]

# %%
timesplit = TimeSeriesSplit(n_splits=10)
for train_idx , test_idx in timesplit.split(feature_tf):
    X_train , X_test = feature_tf[:len(train_idx)],feature_tf[len(train_idx):len(train_idx)+len(test_idx)]
    y_train , y_test = close_price[:len(train_idx)].values.ravel() , close_price[len(train_idx):len(train_idx)+len(test_idx)].values.ravel()

# %%
X_train
# Out:
#              Open         High          Low   Volume
# 0      736.789978   738.989990   732.500000  1301300
# 1      734.590027   747.250000   728.760010  1903800
# 2      750.099976   757.880005   748.739990  1782400
# 3      749.250000   750.849976   740.940002  1718800
# 4      738.599976   750.340027   737.000000  1576700
# ...           ...          ...          ...      ...
# 1141  1475.579956  1486.760010  1448.589966  1245400
# 1142  1464.290039  1468.959961  1436.000000  1746200
# 1143  1465.089966  1490.000000  1465.089966  1187800
# 1144  1494.699951  1516.520020  1489.449951  1435300
# 1145  1543.000000  1593.859985  1532.569946  2482600
#
# [1146 rows x 4 columns]

# %%
X_test
# Out:
#              Open         High          Low   Volume
# 1146  1583.729980  1590.000000  1563.199951  1601000
# 1147  1578.589966  1587.683960  1550.530029  1929300
# 1148  1547.150024  1575.104980  1545.030029  1540000
# 1149  1565.849976  1581.130005  1563.000000  1434700
# 1150  1580.459961  1588.150024  1528.000000  1607100
# ...           ...          ...          ...      ...
# 1255  2041.839966  2057.989990  2026.069946  1954800
# 1256  2051.699951  2072.302002  2039.219971  1367000
# 1257  2065.370117  2078.209961  2041.555054  1154000
# 1258  2044.810059  2058.870117  2010.729980  1418900
# 1259  2038.859985  2050.989990  2014.020020  1493500
#
# [114 rows x 4 columns]

# %%
scaller = MinMaxScaler()
X_train_sc = scaller.fit_transform(feature_tf)
X_test_sc = scaller.transform(X_test)

# %%
X_train_sc = pd.DataFrame(data=X_train_sc, columns=X_train.columns)
X_train_sc
# Out:
#           Open      High       Low    Volume
# 0     0.045427  0.045049  0.048031  0.162878
# 1     0.043908  0.050629  0.045435  0.265691
# 2     0.054617  0.057809  0.059300  0.244975
# 3     0.054030  0.053061  0.053888  0.234122
# 4     0.046676  0.052716  0.051153  0.209873
# ...        ...       ...       ...       ...
# 1255  0.946536  0.936037  0.945672  0.274393
# 1256  0.953344  0.945705  0.954798  0.174090
# 1257  0.962783  0.949695  0.956418  0.137743
# 1258  0.948587  0.936631  0.935028  0.182946
# 1259  0.944479  0.931308  0.937311  0.195676
#
# [1260 rows x 4 columns]

# %%
xtrain = np.array(X_train_sc)
xtest = np.array(X_test_sc)
X_train_sc = xtrain.reshape(X_train.shape[0],1,X_train.shape[1])
X_test_sc = xtest.reshape(X_test.shape[0],1,X_test.shape[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [17], in <cell line: 3>()
#       1 xtrain = np.array(X_train_sc)
#       2 xtest = np.array(X_test_sc)
# ----> 3 X_train_sc = xtrain.reshape(X_train.shape[0],1,X_train.shape[1])
#       4 X_test_sc = xtest.reshape(X_test.shape[0],1,X_test.shape[1])
#
# ValueError: cannot reshape array of size 5040 into shape (1146,1,4)

# %%
X_test_sc.shape

# %%
X_train_sc.shape

# %%
lstm = Sequential()
lstm.add(LSTM(32,input_shape=(1, xtrain.shape[1]),activation='relu',return_sequences=False))
lstm.add(Dense(1))
lstm.compile(optimizer='adam',loss='mean_squared_error')

# %%
lstm.fit(X_train_sc,y_train,batch_size=4,epochs=150,verbose=1)

# %%
predict = lstm.predict(X_test_sc)

# %%
plt.figure(figsize=(10,5))
plt.plot(predict,label='Predict')
plt.plot(y_test,label='Actual')
plt.legend()
plt.show()

# %%
r2_score(y_test,predict)

# %%
mean_squared_error(y_test,predict)
